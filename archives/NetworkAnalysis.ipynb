# %%
import networkx as nx
import matplotlib.pyplot as plt
import community
import types
import pickle 
import pandas as pd
from networkx.algorithms.community.centrality import girvan_newman
from networkx.algorithms.community.kclique import k_clique_communities
from networkx.algorithms.community import greedy_modularity_communities

# %% [markdown]
# ## Todos
#
# TODO: The main thing is just to find a way to partition the graph into a reasonable number of clusters.
#
# TODO: Try other options in networkx.algorithms.community. See https://networkx.github.io/documentation/stable/reference/algorithms/community.html
#
# TODO: Recreate a graph, maybe in GEPHI, using whatever communinty structure we end up with
#
# TODO: LSA / Semantic analysis
#
# TODO: Add diagnostics showing how long some tasks take to run

# %% [markdown]
# ## Load Graph
# Read in the edge list, which contains all relevant information: source author -> target author, number of times cited

# %%
G_directed = nx.read_weighted_edgelist("./small_edge_list.csv", delimiter=",",create_using= nx.DiGraph())
G = nx.read_weighted_edgelist("./small_edge_list.csv", delimiter=",")

# %%
G_tiny = nx.read_weighted_edgelist("./tiny_edge_list.csv", delimiter=",")
G_tiny_directed = nx.read_weighted_edgelist("./tiny_edge_list.csv", delimiter=",", create_using= nx.DiGraph())
G_large_directed = nx.read_weighted_edgelist("./complete_edge_list.csv", delimiter=",",create_using= nx.DiGraph())
G_large = nx.read_weighted_edgelist("./complete_edge_list.csv", delimiter=",")

# %%
# Choose which graph to focus on
G_main = G_large_directed

# %%
# To convert files to graphml 
# nx.write_graphml(G_directed, "small_edge_list.graphml")

# %% [markdown]
# ### Basic Stats

# %%
print(nx.info(G_main))
# print(nx.diameter(G))
# print(nx.average_neighbor_degree(G_large_directed))
# Out:
# Name:
# Type: DiGraph
# Number of nodes: 9925
# Number of edges: 55279
# Average in degree:   5.5697
# Average out degree:   5.5697

# %% [markdown]
# ## Author statistics

# %%
# In degree
degreeTable = pd.DataFrame(G_main.in_degree, columns = ["Name","In Degree"])
sd = degreeTable.sort_values(by=['In Degree'], ascending=False)
sd.head(10)
# Out:
#                 Name  In Degree
# 59         HUSSERL E       1163
# 229      HEIDEGGER M        834
# 1254  MERLEAUPONTY M        685
# 931           KANT I        378
# 2193        SARTRE J        317
# 2275       DERRIDA J        304
# 2753         HEGEL G        300
# 226         ZAHAVI D        289
# 2445       LEVINAS E        282
# 741        RICOEUR P        271

# %%
# Out-degree
degreeTable = pd.DataFrame(G_main.out_degree, columns = ["Name","Out Degree"])
sd = degreeTable.sort_values(by=['Out Degree'], ascending=False)
sd.head(10)
# Out:
#                 Name  Out Degree
# 25           MORAN D         281
# 1339         FUCHS T         245
# 226         ZAHAVI D         223
# 434         FROESE T         196
# 440      GALLAGHER S         195
# 1071  SCHWITZGEBEL E         143
# 163       HEINAMAA S         142
# 10          DEPRAZ N         140
# 200           SASS L         134
# 119       WRATHALL M         131

# %%
# Hubs and Authorities
h,a=nx.hits(G_main)

# First hubs
hubTable =  pd.DataFrame.from_dict(h,orient='index', columns=["Hubitude"])
sd = hubTable.sort_values(by=['Hubitude'], ascending=False)
sd.head(20)
# Out:
#               Hubitude
# ZAHAVI D      0.012030
# DEPRAZ N      0.007946
# MORAN D       0.007362
# CROWELL S     0.005895
# HEINAMAA S    0.005108
# FERENCZ F     0.004465
# GALLAGHER S   0.004223
# SHEETS J      0.003789
# FUCHS T       0.003680
# HARTIMO M     0.003632
# BRIEDIS M     0.003622
# RATCLIFFE M   0.003444
# JONKUS D      0.003443
# SUMMA M       0.003399
# WALDENFELS B  0.003364
# PLOTKA W      0.003290
# WALSH P       0.003275
# FROESE T      0.003193
# SAENZ M       0.003134
# KUHN R        0.003123

# %%
# Then authorities
authTable =  pd.DataFrame.from_dict(a,orient='index', columns=["Authority"])
sd = authTable.sort_values(by=['Authority'], ascending=False)
sd.head(20)
# Out:
#                 Authority
# HUSSERL E        0.058220
# HEIDEGGER M      0.024142
# MERLEAUPONTY M   0.021066
# ZAHAVI D         0.013648
# SARTRE J         0.008362
# DERRIDA J        0.008345
# LEVINAS E        0.008026
# GALLAGHER S      0.007909
# KANT I           0.006420
# DREYFUS H        0.006238
# VARELA F         0.006193
# RICOEUR P        0.006050
# FINK E           0.005556
# DEPRAZ N         0.005325
# HENRY M          0.005259
# MARION J         0.005027
# SCHELER M        0.004974
# BERNET R         0.004880
# STEINBOCK A      0.004820
# WALDENFELS B     0.004723

# %%
# Eigenvector centrality
centrality = nx.eigenvector_centrality(G_directed)
ec_table =  pd.DataFrame.from_dict(centrality,orient='index', columns=["Centrality"])
ect = ec_table.sort_values(by=['Centrality'], ascending=False)
ect.head(20)
# Out:
#                 Centrality
# HUSSERL E         0.405200
# HEIDEGGER M       0.267859
# MERLEAUPONTY M    0.241819
# ZAHAVI D          0.157583
# KANT I            0.143643
# SARTRE J          0.132890
# FINK E            0.125441
# GALLAGHER S       0.116983
# DREYFUS H         0.113294
# LEVINAS E         0.111870
# SCHELER M         0.111787
# DENNETT D         0.110833
# DERRIDA J         0.104042
# SEARLE J          0.102608
# GURWITSCH A       0.099961
# JAMES W           0.094314
# MCDOWELL J        0.092371
# BERNET R          0.090029
# VARELA F          0.089812
# NAGEL T           0.084789

# %% [markdown]
# ## Community Detection

# %% [markdown]
# See https://networkx.github.io/documentation/stable/reference/algorithms/community.html

# %% [markdown]
# ## Helper Methods

# %%
# Currently only prints top level clusters
# todo: recursively print all sub-clusters
def print_clusters(graph, clusters):
    print("Graph has ",len(clusters), "clusters")
    for i,p in enumerate(clusters):
        print("Cluster",(i+1), "has", len(p), "members")

# %%
# Converts nested generators to a list of lists
# The list can then be saved via pickle
# I suspect _extremely_ slow for large lists
# From https://stackoverflow.com/questions/36726129/convert-nested-iterables-to-list
def unfold(iterable):
    ret = []
    for element in iterable:
        if isinstance(element, types.GeneratorType):
            ret.append(unfold(element))
        else:
            ret.append(element)
    return ret

# %% [markdown]
# ### Louvain
#
# https://python-louvain.readthedocs.io/en/latest/api.html
#
# Appears to be deterministic with default settings
#
# Does not seem to work with directed graphs
#
# I think it's using weights but not sure

# %%
import community

# %%
partition = community.best_partition(G_large)

# %%
print_clusters(G_large, partition)
# Out:
# Graph has  9925 clusters
# Cluster 1 has 7 members
# Cluster 2 has 11 members
# Cluster 3 has 10 members
# Cluster 4 has 7 members
# Cluster 5 has 7 members
# Cluster 6 has 9 members
# Cluster 7 has 8 members
# Cluster 8 has 8 members
# Cluster 9 has 8 members
# Cluster 10 has 8 members
# Cluster 11 has 8 members
# Cluster 12 has 8 members
# Cluster 13 has 10 members
# Cluster 14 has 11 members
# Cluster 15 has 9 members
# Cluster 16 has 9 members
# Cluster 17 has 6 members
# Cluster 18 has 7 members
# Cluster 19 has 9 members
# Cluster 20 has 7 members
# Cluster 21 has 7 members
# Cluster 22 has 9 members
# Cluster 23 has 5 members
# Cluster 24 has 9 members
# Cluster 25 has 6 members
# Cluster 26 has 7 members
# Cluster 27 has 6 members
# Cluster 28 has 7 members
# Cluster 29 has 8 members
# Cluster 30 has 9 members
# Cluster 31 has 12 members
# Cluster 32 has 7 members
# Cluster 33 has 8 members
# Cluster 34 has 7 members
# Cluster 35 has 8 members
# Cluster 36 has 8 members
# Cluster 37 has 8 members
# Cluster 38 has 12 members
# Cluster 39 has 8 members
# Cluster 40 has 9 members
# Cluster 41 has 9 members
# Cluster 42 has 9 members
# Cluster 43 has 12 members
# Cluster 44 has 11 members
# Cluster 45 has 6 members
# Cluster 46 has 4 members
# Cluster 47 has 9 members
# Cluster 48 has 7 members
# Cluster 49 has 7 members
# Cluster 50 has 6 members
# Cluster 51 has 8 members
# Cluster 52 has 8 members
# Cluster 53 has 7 members
# Cluster 54 has 10 members
# Cluster 55 has 6 members
# Cluster 56 has 8 members
# Cluster 57 has 8 members
# Cluster 58 has 9 members
# Cluster 59 has 8 members
# Cluster 60 has 9 members
# Cluster 61 has 11 members
# Cluster 62 has 7 members
# Cluster 63 has 14 members
# Cluster 64 has 6 members
# Cluster 65 has 7 members
# Cluster 66 has 5 members
# Cluster 67 has 7 members
# Cluster 68 has 8 members
# Cluster 69 has 8 members
# Cluster 70 has 8 members
# Cluster 71 has 4 members
# Cluster 72 has 8 members
# Cluster 73 has 11 members
# Cluster 74 has 8 members
# Cluster 75 has 6 members
# Cluster 76 has 10 members
# Cluster 77 has 12 members
# Cluster 78 has 11 members
# Cluster 79 has 10 members
# Cluster 80 has 8 members
# Cluster 81 has 7 members
# Cluster 82 has 12 members
# Cluster 83 has 7 members
# Cluster 84 has 9 members
# Cluster 85 has 9 members
# Cluster 86 has 8 members
# Cluster 87 has 11 members
# Cluster 88 has 8 members
# Cluster 89 has 12 members
# Cluster 90 has 10 members
# Cluster 91 has 9 members
# Cluster 92 has 12 members
# Cluster 93 has 8 members
# Cluster 94 has 10 members
# Cluster 95 has 7 members
# Cluster 96 has 12 members
# Cluster 97 has 4 members
# Cluster 98 has 11 members
# Cluster 99 has 11 members
# Cluster 100 has 9 members
# Cluster 101 has 8 members
# Cluster 102 has 10 members
# Cluster 103 has 12 members
# Cluster 104 has 8 members
# Cluster 105 has 9 members
# Cluster 106 has 10 members
# Cluster 107 has 10 members
# Cluster 108 has 9 members
# Cluster 109 has 3 members
# Cluster 110 has 3 members
# Cluster 111 has 11 members
# Cluster 112 has 12 members
# Cluster 113 has 9 members
# Cluster 114 has 7 members
# Cluster 115 has 7 members
# Cluster 116 has 9 members
# Cluster 117 has 8 members
# Cluster 118 has 9 members
# Cluster 119 has 7 members
# Cluster 120 has 10 members
# Cluster 121 has 8 members
# Cluster 122 has 10 members
# Cluster 123 has 6 members
# Cluster 124 has 7 members
# Cluster 125 has 7 members
# Cluster 126 has 14 members
# Cluster 127 has 11 members
# Cluster 128 has 10 members
# Cluster 129 has 8 members
# Cluster 130 has 10 members
# Cluster 131 has 7 members
# Cluster 132 has 8 members
# Cluster 133 has 9 members
# Cluster 134 has 9 members
# Cluster 135 has 9 members
# Cluster 136 has 5 members
# Cluster 137 has 11 members
# Cluster 138 has 11 members
# Cluster 139 has 9 members
# Cluster 140 has 13 members
# Cluster 141 has 9 members
# Cluster 142 has 9 members
# Cluster 143 has 11 members
# Cluster 144 has 9 members
# Cluster 145 has 9 members
# Cluster 146 has 10 members
# Cluster 147 has 4 members
# Cluster 148 has 4 members
# Cluster 149 has 10 members
# Cluster 150 has 11 members
# Cluster 151 has 10 members
# Cluster 152 has 10 members
# Cluster 153 has 9 members
# Cluster 154 has 8 members
# Cluster 155 has 9 members
# Cluster 156 has 12 members
# Cluster 157 has 8 members
# Cluster 158 has 9 members
# Cluster 159 has 8 members
# Cluster 160 has 10 members
# Cluster 161 has 9 members
# Cluster 162 has 7 members
# Cluster 163 has 6 members
# Cluster 164 has 10 members
# Cluster 165 has 10 members
# Cluster 166 has 7 members
# Cluster 167 has 9 members
# Cluster 168 has 8 members
# Cluster 169 has 10 members
# Cluster 170 has 8 members
# Cluster 171 has 9 members
# Cluster 172 has 10 members
# Cluster 173 has 11 members
# Cluster 174 has 8 members
# Cluster 175 has 8 members
# Cluster 176 has 8 members
# Cluster 177 has 9 members
# Cluster 178 has 8 members
# Cluster 179 has 9 members
# Cluster 180 has 8 members
# Cluster 181 has 6 members
# Cluster 182 has 9 members
# Cluster 183 has 9 members
# Cluster 184 has 8 members
# Cluster 185 has 9 members
# Cluster 186 has 4 members
# Cluster 187 has 7 members
# Cluster 188 has 9 members
# Cluster 189 has 6 members
# Cluster 190 has 6 members
# Cluster 191 has 7 members
# Cluster 192 has 8 members
# Cluster 193 has 12 members
# Cluster 194 has 6 members
# Cluster 195 has 7 members
# Cluster 196 has 10 members
# Cluster 197 has 7 members
# Cluster 198 has 11 members
# Cluster 199 has 8 members
# Cluster 200 has 7 members
# Cluster 201 has 6 members
# Cluster 202 has 7 members
# Cluster 203 has 10 members
# Cluster 204 has 11 members
# Cluster 205 has 8 members
# Cluster 206 has 8 members
# Cluster 207 has 12 members
# Cluster 208 has 8 members
# Cluster 209 has 9 members
# Cluster 210 has 10 members
# Cluster 211 has 11 members
# Cluster 212 has 9 members
# Cluster 213 has 10 members
# Cluster 214 has 7 members
# Cluster 215 has 9 members
# Cluster 216 has 10 members
# Cluster 217 has 7 members
# Cluster 218 has 12 members
# Cluster 219 has 12 members
# Cluster 220 has 8 members
# Cluster 221 has 12 members
# Cluster 222 has 8 members
# Cluster 223 has 6 members
# Cluster 224 has 11 members
# Cluster 225 has 4 members
# Cluster 226 has 13 members
# Cluster 227 has 8 members
# Cluster 228 has 8 members
# Cluster 229 has 7 members
# Cluster 230 has 11 members
# Cluster 231 has 8 members
# Cluster 232 has 10 members
# Cluster 233 has 9 members
# Cluster 234 has 8 members
# Cluster 235 has 4 members
# Cluster 236 has 11 members
# Cluster 237 has 4 members
# Cluster 238 has 7 members
# Cluster 239 has 7 members
# Cluster 240 has 7 members
# Cluster 241 has 10 members
# Cluster 242 has 10 members
# Cluster 243 has 8 members
# Cluster 244 has 10 members
# Cluster 245 has 7 members
# Cluster 246 has 9 members
# Cluster 247 has 7 members
# Cluster 248 has 6 members
# Cluster 249 has 11 members
# Cluster 250 has 10 members
# Cluster 251 has 8 members
# Cluster 252 has 8 members
# Cluster 253 has 7 members
# Cluster 254 has 11 members
# Cluster 255 has 9 members
# Cluster 256 has 10 members
# Cluster 257 has 9 members
# Cluster 258 has 14 members
# Cluster 259 has 10 members
# Cluster 260 has 9 members
# Cluster 261 has 7 members
# Cluster 262 has 5 members
# Cluster 263 has 8 members
# Cluster 264 has 10 members
# Cluster 265 has 9 members
# Cluster 266 has 9 members
# Cluster 267 has 7 members
# Cluster 268 has 10 members
# Cluster 269 has 6 members
# Cluster 270 has 11 members
# Cluster 271 has 10 members
# Cluster 272 has 11 members
# Cluster 273 has 9 members
# Cluster 274 has 9 members
# Cluster 275 has 8 members
# Cluster 276 has 7 members
# Cluster 277 has 10 members
# Cluster 278 has 7 members
# Cluster 279 has 11 members
# Cluster 280 has 7 members
# Cluster 281 has 7 members
# Cluster 282 has 12 members
# Cluster 283 has 9 members
# Cluster 284 has 7 members
# Cluster 285 has 7 members
# Cluster 286 has 7 members
# Cluster 287 has 6 members
# Cluster 288 has 9 members
# Cluster 289 has 10 members
# Cluster 290 has 8 members
# Cluster 291 has 10 members
# Cluster 292 has 11 members
# Cluster 293 has 8 members
# Cluster 294 has 8 members
# Cluster 295 has 7 members
# Cluster 296 has 8 members
# Cluster 297 has 9 members
# Cluster 298 has 7 members
# Cluster 299 has 9 members
# Cluster 300 has 10 members
# Cluster 301 has 7 members
# Cluster 302 has 7 members
# Cluster 303 has 6 members
# Cluster 304 has 5 members
# Cluster 305 has 10 members
# Cluster 306 has 7 members
# Cluster 307 has 8 members
# Cluster 308 has 7 members
# Cluster 309 has 10 members
# Cluster 310 has 8 members
# Cluster 311 has 8 members
# Cluster 312 has 10 members
# Cluster 313 has 7 members
# Cluster 314 has 7 members
# Cluster 315 has 9 members
# Cluster 316 has 9 members
# Cluster 317 has 8 members
# Cluster 318 has 9 members
# Cluster 319 has 12 members
# Cluster 320 has 5 members
# Cluster 321 has 8 members
# Cluster 322 has 7 members
# Cluster 323 has 6 members
# Cluster 324 has 10 members
# Cluster 325 has 6 members
# Cluster 326 has 6 members
# Cluster 327 has 6 members
# Cluster 328 has 8 members
# Cluster 329 has 9 members
# Cluster 330 has 12 members
# Cluster 331 has 9 members
# Cluster 332 has 10 members
# Cluster 333 has 6 members
# Cluster 334 has 13 members
# Cluster 335 has 7 members
# Cluster 336 has 12 members
# Cluster 337 has 8 members
# Cluster 338 has 9 members
# Cluster 339 has 7 members
# Cluster 340 has 14 members
# Cluster 341 has 7 members
# Cluster 342 has 7 members
# Cluster 343 has 7 members
# Cluster 344 has 9 members
# Cluster 345 has 8 members
# Cluster 346 has 9 members
# Cluster 347 has 8 members
# Cluster 348 has 7 members
# Cluster 349 has 7 members
# Cluster 350 has 8 members
# Cluster 351 has 9 members
# Cluster 352 has 9 members
# Cluster 353 has 8 members
# Cluster 354 has 7 members
# Cluster 355 has 10 members
# Cluster 356 has 7 members
# Cluster 357 has 9 members
# Cluster 358 has 11 members
# Cluster 359 has 9 members
# Cluster 360 has 8 members
# Cluster 361 has 12 members
# Cluster 362 has 3 members
# Cluster 363 has 4 members
# Cluster 364 has 6 members
# Cluster 365 has 11 members
# Cluster 366 has 8 members
# Cluster 367 has 11 members
# Cluster 368 has 4 members
# Cluster 369 has 4 members
# Cluster 370 has 4 members
# Cluster 371 has 4 members
# Cluster 372 has 4 members
# Cluster 373 has 4 members
# Cluster 374 has 4 members
# Cluster 375 has 4 members
# Cluster 376 has 8 members
# Cluster 377 has 10 members
# Cluster 378 has 7 members
# Cluster 379 has 11 members
# Cluster 380 has 8 members
# Cluster 381 has 6 members
# Cluster 382 has 9 members
# Cluster 383 has 10 members
# Cluster 384 has 6 members
# Cluster 385 has 4 members
# Cluster 386 has 4 members
# Cluster 387 has 11 members
# Cluster 388 has 7 members
# Cluster 389 has 9 members
# Cluster 390 has 7 members
# Cluster 391 has 7 members
# Cluster 392 has 4 members
# Cluster 393 has 6 members
# Cluster 394 has 12 members
# Cluster 395 has 9 members
# Cluster 396 has 9 members
# Cluster 397 has 7 members
# Cluster 398 has 9 members
# Cluster 399 has 8 members
# Cluster 400 has 8 members
# Cluster 401 has 9 members
# Cluster 402 has 7 members
# Cluster 403 has 9 members
# Cluster 404 has 6 members
# Cluster 405 has 7 members
# Cluster 406 has 9 members
# Cluster 407 has 7 members
# Cluster 408 has 10 members
# Cluster 409 has 9 members
# Cluster 410 has 11 members
# Cluster 411 has 7 members
# Cluster 412 has 8 members
# Cluster 413 has 10 members
# Cluster 414 has 10 members
# Cluster 415 has 9 members
# Cluster 416 has 9 members
# Cluster 417 has 7 members
# Cluster 418 has 8 members
# Cluster 419 has 8 members
# Cluster 420 has 8 members
# Cluster 421 has 8 members
# Cluster 422 has 10 members
# Cluster 423 has 11 members
# Cluster 424 has 11 members
# Cluster 425 has 11 members
# Cluster 426 has 7 members
# Cluster 427 has 8 members
# Cluster 428 has 8 members
# Cluster 429 has 11 members
# Cluster 430 has 11 members
# Cluster 431 has 10 members
# Cluster 432 has 11 members
# Cluster 433 has 10 members
# Cluster 434 has 11 members
# Cluster 435 has 8 members
# Cluster 436 has 10 members
# Cluster 437 has 7 members
# Cluster 438 has 12 members
# Cluster 439 has 7 members
# Cluster 440 has 9 members
# Cluster 441 has 11 members
# Cluster 442 has 10 members
# Cluster 443 has 8 members
# Cluster 444 has 8 members
# Cluster 445 has 9 members
# Cluster 446 has 8 members
# Cluster 447 has 8 members
# Cluster 448 has 8 members
# Cluster 449 has 6 members
# Cluster 450 has 14 members
# Cluster 451 has 7 members
# Cluster 452 has 6 members
# Cluster 453 has 10 members
# Cluster 454 has 14 members
# Cluster 455 has 7 members
# Cluster 456 has 9 members
# Cluster 457 has 8 members
# Cluster 458 has 8 members
# Cluster 459 has 10 members
# Cluster 460 has 10 members
# Cluster 461 has 9 members
# Cluster 462 has 8 members
# Cluster 463 has 9 members
# Cluster 464 has 10 members
# Cluster 465 has 10 members
# Cluster 466 has 7 members
# Cluster 467 has 9 members
# Cluster 468 has 8 members
# Cluster 469 has 9 members
# Cluster 470 has 10 members
# Cluster 471 has 10 members
# Cluster 472 has 10 members
# Cluster 473 has 9 members
# Cluster 474 has 6 members
# Cluster 475 has 11 members
# Cluster 476 has 7 members
# Cluster 477 has 14 members
# Cluster 478 has 11 members
# Cluster 479 has 10 members
# Cluster 480 has 11 members
# Cluster 481 has 8 members
# Cluster 482 has 8 members
# Cluster 483 has 8 members
# Cluster 484 has 5 members
# Cluster 485 has 7 members
# Cluster 486 has 11 members
# Cluster 487 has 8 members
# Cluster 488 has 10 members
# Cluster 489 has 8 members
# Cluster 490 has 11 members
# Cluster 491 has 6 members
# Cluster 492 has 8 members
# Cluster 493 has 6 members
# Cluster 494 has 6 members
# Cluster 495 has 11 members
# Cluster 496 has 11 members
# Cluster 497 has 9 members
# Cluster 498 has 8 members
# Cluster 499 has 8 members
# Cluster 500 has 11 members
# Cluster 501 has 7 members
# Cluster 502 has 8 members
# Cluster 503 has 8 members
# Cluster 504 has 7 members
# Cluster 505 has 10 members
# Cluster 506 has 8 members
# Cluster 507 has 8 members
# Cluster 508 has 8 members
# Cluster 509 has 9 members
# Cluster 510 has 9 members
# Cluster 511 has 8 members
# Cluster 512 has 7 members
# Cluster 513 has 8 members
# Cluster 514 has 5 members
# Cluster 515 has 12 members
# Cluster 516 has 6 members
# Cluster 517 has 6 members
# Cluster 518 has 6 members
# Cluster 519 has 9 members
# Cluster 520 has 7 members
# Cluster 521 has 10 members
# Cluster 522 has 9 members
# Cluster 523 has 7 members
# Cluster 524 has 10 members
# Cluster 525 has 7 members
# Cluster 526 has 7 members
# Cluster 527 has 9 members
# Cluster 528 has 5 members
# Cluster 529 has 9 members
# Cluster 530 has 7 members
# Cluster 531 has 7 members
# Cluster 532 has 6 members
# Cluster 533 has 11 members
# Cluster 534 has 6 members
# Cluster 535 has 10 members
# Cluster 536 has 11 members
# Cluster 537 has 13 members
# Cluster 538 has 14 members
# Cluster 539 has 7 members
# Cluster 540 has 9 members
# Cluster 541 has 8 members
# Cluster 542 has 9 members
# Cluster 543 has 9 members
# Cluster 544 has 8 members
# Cluster 545 has 7 members
# Cluster 546 has 7 members
# Cluster 547 has 5 members
# Cluster 548 has 10 members
# Cluster 549 has 10 members
# Cluster 550 has 8 members
# Cluster 551 has 9 members
# Cluster 552 has 9 members
# Cluster 553 has 7 members
# Cluster 554 has 7 members
# Cluster 555 has 7 members
# Cluster 556 has 7 members
# Cluster 557 has 11 members
# Cluster 558 has 7 members
# Cluster 559 has 9 members
# Cluster 560 has 8 members
# Cluster 561 has 8 members
# Cluster 562 has 7 members
# Cluster 563 has 9 members
# Cluster 564 has 11 members
# Cluster 565 has 9 members
# Cluster 566 has 6 members
# Cluster 567 has 9 members
# Cluster 568 has 9 members
# Cluster 569 has 7 members
# Cluster 570 has 8 members
# Cluster 571 has 10 members
# Cluster 572 has 7 members
# Cluster 573 has 8 members
# Cluster 574 has 9 members
# Cluster 575 has 8 members
# Cluster 576 has 9 members
# Cluster 577 has 8 members
# Cluster 578 has 7 members
# Cluster 579 has 9 members
# Cluster 580 has 7 members
# Cluster 581 has 8 members
# Cluster 582 has 10 members
# Cluster 583 has 9 members
# Cluster 584 has 8 members
# Cluster 585 has 9 members
# Cluster 586 has 7 members
# Cluster 587 has 7 members
# Cluster 588 has 5 members
# Cluster 589 has 5 members
# Cluster 590 has 12 members
# Cluster 591 has 10 members
# Cluster 592 has 10 members
# Cluster 593 has 7 members
# Cluster 594 has 6 members
# Cluster 595 has 6 members
# Cluster 596 has 6 members
# Cluster 597 has 8 members
# Cluster 598 has 5 members
# Cluster 599 has 9 members
# Cluster 600 has 6 members
# Cluster 601 has 8 members
# Cluster 602 has 10 members
# Cluster 603 has 8 members
# Cluster 604 has 9 members
# Cluster 605 has 11 members
# Cluster 606 has 9 members
# Cluster 607 has 10 members
# Cluster 608 has 8 members
# Cluster 609 has 9 members
# Cluster 610 has 9 members
# Cluster 611 has 10 members
# Cluster 612 has 7 members
# Cluster 613 has 10 members
# Cluster 614 has 12 members
# Cluster 615 has 6 members
# Cluster 616 has 13 members
# Cluster 617 has 7 members
# Cluster 618 has 10 members
# Cluster 619 has 11 members
# Cluster 620 has 9 members
# Cluster 621 has 8 members
# Cluster 622 has 8 members
# Cluster 623 has 8 members
# Cluster 624 has 7 members
# Cluster 625 has 8 members
# Cluster 626 has 9 members
# Cluster 627 has 12 members
# Cluster 628 has 10 members
# Cluster 629 has 8 members
# Cluster 630 has 10 members
# Cluster 631 has 11 members
# Cluster 632 has 10 members
# Cluster 633 has 9 members
# Cluster 634 has 9 members
# Cluster 635 has 7 members
# Cluster 636 has 6 members
# Cluster 637 has 7 members
# Cluster 638 has 9 members
# Cluster 639 has 9 members
# Cluster 640 has 8 members
# Cluster 641 has 7 members
# Cluster 642 has 9 members
# Cluster 643 has 7 members
# Cluster 644 has 7 members
# Cluster 645 has 10 members
# Cluster 646 has 13 members
# Cluster 647 has 11 members
# Cluster 648 has 6 members
# Cluster 649 has 11 members
# Cluster 650 has 8 members
# Cluster 651 has 7 members
# Cluster 652 has 7 members
# Cluster 653 has 8 members
# Cluster 654 has 10 members
# Cluster 655 has 11 members
# Cluster 656 has 7 members
# Cluster 657 has 12 members
# Cluster 658 has 12 members
# Cluster 659 has 8 members
# Cluster 660 has 8 members
# Cluster 661 has 8 members
# Cluster 662 has 8 members
# Cluster 663 has 8 members
# Cluster 664 has 13 members
# Cluster 665 has 10 members
# Cluster 666 has 11 members
# Cluster 667 has 8 members
# Cluster 668 has 8 members
# Cluster 669 has 6 members
# Cluster 670 has 17 members
# Cluster 671 has 8 members
# Cluster 672 has 7 members
# Cluster 673 has 9 members
# Cluster 674 has 8 members
# Cluster 675 has 3 members
# Cluster 676 has 3 members
# Cluster 677 has 7 members
# Cluster 678 has 7 members
# Cluster 679 has 7 members
# Cluster 680 has 8 members
# Cluster 681 has 9 members
# Cluster 682 has 10 members
# Cluster 683 has 11 members
# Cluster 684 has 9 members
# Cluster 685 has 11 members
# Cluster 686 has 5 members
# Cluster 687 has 11 members
# Cluster 688 has 6 members
# Cluster 689 has 6 members
# Cluster 690 has 7 members
# Cluster 691 has 9 members
# Cluster 692 has 9 members
# Cluster 693 has 11 members
# Cluster 694 has 6 members
# Cluster 695 has 8 members
# Cluster 696 has 9 members
# Cluster 697 has 8 members
# Cluster 698 has 10 members
# Cluster 699 has 7 members
# Cluster 700 has 7 members
# Cluster 701 has 9 members
# Cluster 702 has 10 members
# Cluster 703 has 8 members
# Cluster 704 has 7 members
# Cluster 705 has 9 members
# Cluster 706 has 8 members
# Cluster 707 has 10 members
# Cluster 708 has 7 members
# Cluster 709 has 11 members
# Cluster 710 has 10 members
# Cluster 711 has 6 members
# Cluster 712 has 7 members
# Cluster 713 has 12 members
# Cluster 714 has 10 members
# Cluster 715 has 9 members
# Cluster 716 has 6 members
# Cluster 717 has 7 members
# Cluster 718 has 9 members
# Cluster 719 has 7 members
# Cluster 720 has 6 members
# Cluster 721 has 8 members
# Cluster 722 has 8 members
# Cluster 723 has 10 members
# Cluster 724 has 8 members
# Cluster 725 has 8 members
# Cluster 726 has 9 members
# Cluster 727 has 9 members
# Cluster 728 has 13 members
# Cluster 729 has 9 members
# Cluster 730 has 9 members
# Cluster 731 has 9 members
# Cluster 732 has 9 members
# Cluster 733 has 7 members
# Cluster 734 has 8 members
# Cluster 735 has 11 members
# Cluster 736 has 8 members
# Cluster 737 has 10 members
# Cluster 738 has 6 members
# Cluster 739 has 10 members
# Cluster 740 has 10 members
# Cluster 741 has 6 members
# Cluster 742 has 9 members
# Cluster 743 has 6 members
# Cluster 744 has 8 members
# Cluster 745 has 8 members
# Cluster 746 has 8 members
# Cluster 747 has 10 members
# Cluster 748 has 11 members
# Cluster 749 has 9 members
# Cluster 750 has 7 members
# Cluster 751 has 6 members
# Cluster 752 has 9 members
# Cluster 753 has 8 members
# Cluster 754 has 7 members
# Cluster 755 has 6 members
# Cluster 756 has 5 members
# Cluster 757 has 9 members
# Cluster 758 has 8 members
# Cluster 759 has 13 members
# Cluster 760 has 10 members
# Cluster 761 has 7 members
# Cluster 762 has 14 members
# Cluster 763 has 7 members
# Cluster 764 has 8 members
# Cluster 765 has 9 members
# Cluster 766 has 9 members
# Cluster 767 has 9 members
# Cluster 768 has 8 members
# Cluster 769 has 8 members
# Cluster 770 has 8 members
# Cluster 771 has 9 members
# Cluster 772 has 8 members
# Cluster 773 has 8 members
# Cluster 774 has 13 members
# Cluster 775 has 8 members
# Cluster 776 has 10 members
# Cluster 777 has 8 members
# Cluster 778 has 9 members
# Cluster 779 has 9 members
# Cluster 780 has 11 members
# Cluster 781 has 12 members
# Cluster 782 has 11 members
# Cluster 783 has 10 members
# Cluster 784 has 13 members
# Cluster 785 has 6 members
# Cluster 786 has 7 members
# Cluster 787 has 11 members
# Cluster 788 has 6 members
# Cluster 789 has 10 members
# Cluster 790 has 7 members
# Cluster 791 has 9 members
# Cluster 792 has 8 members
# Cluster 793 has 9 members
# Cluster 794 has 7 members
# Cluster 795 has 11 members
# Cluster 796 has 9 members
# Cluster 797 has 7 members
# Cluster 798 has 13 members
# Cluster 799 has 7 members
# Cluster 800 has 8 members
# Cluster 801 has 7 members
# Cluster 802 has 10 members
# Cluster 803 has 7 members
# Cluster 804 has 7 members
# Cluster 805 has 6 members
# Cluster 806 has 7 members
# Cluster 807 has 7 members
# Cluster 808 has 7 members
# Cluster 809 has 9 members
# Cluster 810 has 8 members
# Cluster 811 has 7 members
# Cluster 812 has 9 members
# Cluster 813 has 13 members
# Cluster 814 has 9 members
# Cluster 815 has 4 members
# Cluster 816 has 10 members
# Cluster 817 has 7 members
# Cluster 818 has 11 members
# Cluster 819 has 14 members
# Cluster 820 has 11 members
# Cluster 821 has 11 members
# Cluster 822 has 9 members
# Cluster 823 has 11 members
# Cluster 824 has 9 members
# Cluster 825 has 12 members
# Cluster 826 has 12 members
# Cluster 827 has 11 members
# Cluster 828 has 8 members
# Cluster 829 has 8 members
# Cluster 830 has 9 members
# Cluster 831 has 7 members
# Cluster 832 has 7 members
# Cluster 833 has 10 members
# Cluster 834 has 17 members
# Cluster 835 has 8 members
# Cluster 836 has 8 members
# Cluster 837 has 6 members
# Cluster 838 has 10 members
# Cluster 839 has 9 members
# Cluster 840 has 7 members
# Cluster 841 has 6 members
# Cluster 842 has 8 members
# Cluster 843 has 9 members
# Cluster 844 has 10 members
# Cluster 845 has 8 members
# Cluster 846 has 7 members
# Cluster 847 has 8 members
# Cluster 848 has 11 members
# Cluster 849 has 6 members
# Cluster 850 has 8 members
# Cluster 851 has 9 members
# Cluster 852 has 8 members
# Cluster 853 has 11 members
# Cluster 854 has 8 members
# Cluster 855 has 9 members
# Cluster 856 has 7 members
# Cluster 857 has 10 members
# Cluster 858 has 10 members
# Cluster 859 has 9 members
# Cluster 860 has 8 members
# Cluster 861 has 7 members
# Cluster 862 has 9 members
# Cluster 863 has 5 members
# Cluster 864 has 10 members
# Cluster 865 has 10 members
# Cluster 866 has 8 members
# Cluster 867 has 9 members
# Cluster 868 has 7 members
# Cluster 978 has 6 members
# Cluster 979 has 10 members
# Cluster 980 has 8 members
# Cluster 981 has 9 members
# Cluster 982 has 6 members
# Cluster 983 has 6 members
# Cluster 984 has 8 members
# Cluster 985 has 10 members
# Cluster 986 has 6 members
# Cluster 987 has 9 members
# Cluster 988 has 13 members
# Cluster 989 has 11 members
# Cluster 990 has 10 members
# Cluster 991 has 12 members
# Cluster 992 has 6 members
# Cluster 993 has 6 members
# Cluster 994 has 7 members
# Cluster 995 has 7 members
# Cluster 996 has 12 members
# Cluster 997 has 8 members
# Cluster 998 has 7 members
# Cluster 999 has 8 members
# Cluster 1000 has 7 members
# Cluster 1001 has 7 members
# Cluster 1002 has 10 members
# Cluster 1003 has 8 members
# Cluster 1004 has 9 members
# Cluster 1005 has 9 members
# Cluster 1006 has 7 members
# Cluster 1007 has 9 members
# Cluster 1008 has 10 members
# Cluster 1009 has 7 members
# Cluster 1010 has 7 members
# Cluster 1011 has 6 members
# Cluster 1012 has 7 members
# Cluster 1013 has 7 members
# Cluster 1014 has 8 members
# Cluster 1015 has 9 members
# Cluster 1016 has 7 members
# Cluster 1017 has 11 members
# Cluster 1018 has 8 members
# Cluster 1019 has 7 members
# Cluster 1020 has 5 members
# Cluster 1021 has 9 members
# Cluster 1022 has 9 members
# Cluster 1023 has 6 members
# Cluster 1024 has 4 members
# Cluster 1025 has 8 members
# Cluster 1026 has 5 members
# Cluster 1027 has 4 members
# Cluster 1028 has 7 members
# Cluster 1029 has 9 members
# Cluster 1030 has 7 members
# Cluster 1031 has 8 members
# Cluster 1032 has 8 members
# Cluster 1033 has 10 members
# Cluster 1034 has 9 members
# Cluster 1035 has 8 members
# Cluster 1036 has 11 members
# Cluster 1037 has 10 members
# Cluster 1038 has 9 members
# Cluster 1039 has 16 members
# Cluster 1040 has 13 members
# Cluster 1041 has 11 members
# Cluster 1042 has 8 members
# Cluster 1043 has 4 members
# Cluster 1044 has 8 members
# Cluster 1045 has 11 members
# Cluster 1046 has 13 members
# Cluster 1047 has 7 members
# Cluster 1048 has 7 members
# Cluster 1049 has 8 members
# Cluster 1050 has 10 members
# Cluster 1051 has 9 members
# Cluster 1052 has 12 members
# Cluster 1053 has 8 members
# Cluster 1054 has 6 members
# Cluster 1055 has 9 members
# Cluster 1056 has 9 members
# Cluster 1057 has 9 members
# Cluster 1058 has 8 members
# Cluster 1059 has 9 members
# Cluster 1060 has 7 members
# Cluster 1061 has 9 members
# Cluster 1062 has 7 members
# Cluster 1063 has 6 members
# Cluster 1064 has 10 members
# Cluster 1065 has 6 members
# Cluster 1066 has 7 members
# Cluster 1067 has 8 members
# Cluster 1068 has 9 members
# Cluster 1069 has 11 members
# Cluster 1070 has 9 members
# Cluster 1071 has 11 members
# Cluster 1072 has 14 members
# Cluster 1073 has 9 members
# Cluster 1074 has 9 members
# Cluster 1075 has 9 members
# Cluster 1076 has 9 members
# Cluster 1077 has 5 members
# Cluster 1078 has 9 members
# Cluster 1079 has 10 members
# Cluster 1080 has 10 members
# Cluster 1182 has 10 members
# Cluster 1183 has 9 members
# Cluster 1184 has 9 members
# Cluster 1185 has 6 members
# Cluster 1186 has 7 members
# Cluster 1187 has 7 members
# Cluster 1188 has 9 members
# Cluster 1189 has 6 members
# Cluster 1190 has 10 members
# Cluster 1191 has 10 members
# Cluster 1192 has 8 members
# Cluster 1193 has 11 members
# Cluster 1194 has 8 members
# Cluster 1195 has 11 members
# Cluster 1196 has 8 members
# Cluster 1197 has 12 members
# Cluster 1198 has 6 members
# Cluster 1199 has 7 members
# Cluster 1200 has 11 members
# Cluster 1201 has 10 members
# Cluster 1202 has 9 members
# Cluster 1203 has 7 members
# Cluster 1204 has 10 members
# Cluster 1205 has 9 members
# Cluster 1206 has 10 members
# Cluster 1207 has 10 members
# Cluster 1208 has 6 members
# Cluster 1209 has 10 members
# Cluster 1210 has 9 members
# Cluster 1211 has 10 members
# Cluster 1212 has 14 members
# Cluster 1213 has 7 members
# Cluster 1214 has 9 members
# Cluster 1215 has 10 members
# Cluster 1216 has 7 members
# Cluster 1217 has 6 members
# Cluster 1218 has 9 members
# Cluster 1219 has 7 members
# Cluster 1220 has 10 members
# Cluster 1221 has 9 members
# Cluster 1222 has 9 members
# Cluster 1223 has 13 members
# Cluster 1224 has 4 members
# Cluster 1225 has 7 members
# Cluster 1226 has 9 members
# Cluster 1227 has 9 members
# Cluster 1228 has 8 members
# Cluster 1229 has 7 members
# Cluster 1230 has 9 members
# Cluster 1231 has 8 members
# Cluster 1232 has 8 members
# Cluster 1233 has 10 members
# Cluster 1234 has 6 members
# Cluster 1235 has 8 members
# Cluster 1236 has 9 members
# Cluster 1237 has 9 members
# Cluster 1238 has 8 members
# Cluster 1239 has 9 members
# Cluster 1240 has 8 members
# Cluster 1241 has 7 members
# Cluster 1242 has 11 members
# Cluster 1243 has 6 members
# Cluster 1244 has 9 members
# Cluster 1245 has 8 members
# Cluster 1246 has 13 members
# Cluster 1247 has 9 members
# Cluster 1248 has 12 members
# Cluster 1249 has 6 members
# Cluster 1250 has 6 members
# Cluster 1251 has 7 members
# Cluster 1252 has 10 members
# Cluster 1253 has 8 members
# Cluster 1254 has 7 members
# Cluster 1255 has 14 members
# Cluster 1256 has 10 members
# Cluster 1257 has 11 members
# Cluster 1258 has 10 members
# Cluster 1259 has 7 members
# Cluster 1260 has 9 members
# Cluster 1261 has 7 members
# Cluster 1262 has 10 members
# Cluster 1263 has 16 members
# Cluster 1264 has 8 members
# Cluster 1265 has 10 members
# Cluster 1266 has 8 members
# Cluster 1267 has 8 members
# Cluster 1268 has 7 members
# Cluster 1269 has 8 members
# Cluster 1270 has 10 members
# Cluster 1271 has 10 members
# Cluster 1272 has 8 members
# Cluster 1273 has 12 members
# Cluster 1274 has 11 members
# Cluster 1275 has 12 members
# Cluster 1276 has 10 members
# Cluster 1277 has 8 members
# Cluster 1278 has 10 members
# Cluster 1279 has 9 members
# Cluster 1280 has 12 members
# Cluster 1281 has 7 members
# Cluster 1282 has 9 members
# Cluster 1486 has 10 members
# Cluster 1487 has 8 members
# Cluster 1488 has 10 members
# Cluster 1489 has 13 members
# Cluster 1490 has 9 members
# Cluster 1491 has 9 members
# Cluster 1492 has 10 members
# Cluster 1493 has 8 members
# Cluster 1494 has 11 members
# Cluster 1495 has 11 members
# Cluster 1496 has 9 members
# Cluster 1497 has 12 members
# Cluster 1498 has 7 members
# Cluster 1499 has 7 members
# Cluster 1500 has 7 members
# Cluster 1501 has 9 members
# Cluster 1502 has 5 members
# Cluster 1503 has 7 members
# Cluster 1504 has 12 members
# Cluster 1505 has 12 members
# Cluster 1506 has 10 members
# Cluster 1507 has 12 members
# Cluster 1508 has 8 members
# Cluster 1509 has 9 members
# Cluster 1510 has 9 members
# Cluster 1511 has 8 members
# Cluster 1512 has 7 members
# Cluster 1513 has 9 members
# Cluster 1514 has 6 members
# Cluster 1515 has 7 members
# Cluster 1516 has 6 members
# Cluster 1517 has 9 members
# Cluster 1518 has 7 members
# Cluster 1519 has 10 members
# Cluster 1520 has 10 members
# Cluster 1521 has 7 members
# Cluster 1522 has 9 members
# Cluster 1523 has 11 members
# Cluster 1524 has 12 members
# Cluster 1525 has 8 members
# Cluster 1526 has 10 members
# Cluster 1527 has 7 members
# Cluster 1528 has 10 members
# Cluster 1529 has 8 members
# Cluster 1530 has 10 members
# Cluster 1531 has 10 members
# Cluster 1532 has 8 members
# Cluster 1533 has 14 members
# Cluster 1534 has 7 members
# Cluster 1535 has 8 members
# Cluster 1536 has 12 members
# Cluster 1537 has 8 members
# Cluster 1538 has 12 members
# Cluster 1539 has 11 members
# Cluster 1540 has 9 members
# Cluster 1541 has 9 members
# Cluster 1542 has 12 members
# Cluster 1543 has 9 members
# Cluster 1544 has 7 members
# Cluster 1545 has 10 members
# Cluster 1546 has 9 members
# Cluster 1547 has 9 members
# Cluster 1548 has 8 members
# Cluster 1549 has 7 members
# Cluster 1550 has 8 members
# Cluster 1551 has 7 members
# Cluster 1552 has 11 members
# Cluster 1553 has 11 members
# Cluster 1554 has 11 members
# Cluster 1555 has 6 members
# Cluster 1556 has 10 members
# Cluster 1557 has 4 members
# Cluster 1558 has 7 members
# Cluster 1559 has 4 members
# Cluster 1560 has 11 members
# Cluster 1561 has 8 members
# Cluster 1562 has 7 members
# Cluster 1563 has 7 members
# Cluster 1564 has 7 members
# Cluster 1565 has 4 members
# Cluster 1566 has 10 members
# Cluster 1567 has 6 members
# Cluster 1568 has 8 members
# Cluster 1569 has 9 members
# Cluster 1570 has 11 members
# Cluster 1571 has 10 members
# Cluster 1572 has 7 members
# Cluster 1573 has 8 members
# Cluster 1574 has 7 members
# Cluster 1575 has 10 members
# Cluster 1576 has 10 members
# Cluster 1577 has 8 members
# Cluster 1578 has 12 members
# Cluster 1579 has 7 members
# Cluster 1580 has 10 members
# Cluster 1581 has 10 members
# Cluster 1582 has 7 members
# Cluster 1583 has 9 members
# Cluster 1584 has 15 members
# Cluster 1585 has 6 members
# Cluster 1586 has 8 members
# Cluster 1587 has 8 members
# Cluster 1588 has 6 members
# Cluster 1589 has 8 members
# Cluster 1590 has 10 members
# Cluster 1591 has 9 members
# Cluster 1592 has 11 members
# Cluster 1593 has 5 members
# Cluster 1594 has 9 members
# Cluster 1595 has 11 members
# Cluster 1596 has 10 members
# Cluster 1597 has 7 members
# Cluster 1598 has 7 members
# Cluster 1599 has 12 members
# Cluster 1600 has 10 members
# Cluster 1601 has 10 members
# Cluster 1602 has 8 members
# Cluster 1603 has 14 members
# Cluster 1604 has 13 members
# Cluster 1605 has 11 members
# Cluster 1606 has 8 members
# Cluster 1607 has 11 members
# Cluster 1608 has 7 members
# Cluster 1609 has 8 members
# Cluster 1610 has 9 members
# Cluster 1611 has 13 members
# Cluster 1612 has 8 members
# Cluster 1613 has 9 members
# Cluster 1614 has 8 members
# Cluster 1615 has 6 members
# Cluster 1616 has 13 members
# Cluster 1617 has 7 members
# Cluster 1618 has 7 members
# Cluster 1619 has 9 members
# Cluster 1620 has 10 members
# Cluster 1621 has 8 members
# Cluster 1622 has 10 members
# Cluster 1623 has 9 members
# Cluster 1624 has 7 members
# Cluster 1625 has 8 members
# Cluster 1626 has 12 members
# Cluster 1627 has 9 members
# Cluster 1628 has 8 members
# Cluster 1629 has 7 members
# Cluster 1630 has 16 members
# Cluster 1631 has 10 members
# Cluster 1632 has 13 members
# Cluster 1633 has 5 members
# Cluster 1634 has 8 members
# Cluster 1635 has 13 members
# Cluster 1636 has 9 members
# Cluster 1637 has 7 members
# Cluster 1638 has 11 members
# Cluster 1639 has 10 members
# Cluster 1640 has 12 members
# Cluster 1641 has 12 members
# Cluster 1642 has 8 members
# Cluster 1643 has 10 members
# Cluster 1644 has 4 members
# Cluster 1645 has 8 members
# Cluster 1646 has 9 members
# Cluster 1647 has 7 members
# Cluster 1648 has 8 members
# Cluster 1649 has 11 members
# Cluster 1650 has 5 members
# Cluster 1651 has 9 members
# Cluster 1652 has 10 members
# Cluster 1653 has 9 members
# Cluster 1654 has 8 members
# Cluster 1655 has 7 members
# Cluster 1656 has 10 members
# Cluster 1657 has 10 members
# Cluster 1658 has 7 members
# Cluster 1659 has 9 members
# Cluster 1660 has 9 members
# Cluster 1661 has 9 members
# Cluster 1662 has 9 members
# Cluster 1663 has 6 members
# Cluster 1664 has 10 members
# Cluster 1665 has 12 members
# Cluster 1666 has 10 members
# Cluster 1667 has 7 members
# Cluster 1668 has 8 members
# Cluster 1669 has 12 members
# Cluster 1670 has 11 members
# Cluster 1671 has 8 members
# Cluster 1672 has 3 members
# Cluster 1673 has 9 members
# Cluster 1674 has 9 members
# Cluster 1675 has 8 members
# Cluster 1676 has 10 members
# Cluster 1677 has 8 members
# Cluster 1678 has 10 members
# Cluster 1679 has 11 members
# Cluster 1680 has 11 members
# Cluster 1681 has 9 members
# Cluster 1682 has 8 members
# Cluster 1683 has 11 members
# Cluster 1684 has 7 members
# Cluster 1685 has 9 members
# Cluster 1686 has 9 members
# Cluster 1687 has 11 members
# Cluster 9737 has 6 members
# Cluster 9738 has 9 members
# Cluster 9739 has 10 members
# Cluster 9740 has 7 members
# Cluster 9741 has 9 members
# Cluster 9742 has 6 members
# Cluster 9743 has 6 members
# Cluster 9744 has 8 members
# Cluster 9745 has 10 members
# Cluster 9746 has 10 members
# Cluster 9747 has 14 members
# Cluster 9748 has 9 members
# Cluster 9749 has 8 members
# Cluster 9750 has 7 members
# Cluster 9751 has 10 members
# Cluster 9752 has 9 members
# Cluster 9753 has 13 members
# Cluster 9754 has 6 members
# Cluster 9755 has 9 members
# Cluster 9756 has 10 members
# Cluster 9757 has 5 members
# Cluster 9758 has 5 members
# Cluster 9759 has 10 members
# Cluster 9760 has 7 members
# Cluster 9761 has 8 members
# Cluster 9762 has 10 members
# Cluster 9763 has 10 members
# Cluster 9764 has 11 members
# Cluster 9765 has 8 members
# Cluster 9766 has 8 members
# Cluster 9767 has 6 members
# Cluster 9768 has 10 members
# Cluster 9769 has 7 members
# Cluster 9770 has 8 members
# Cluster 9771 has 12 members
# Cluster 9772 has 9 members
# Cluster 9773 has 10 members
# Cluster 9774 has 10 members
# Cluster 9775 has 8 members
# Cluster 9776 has 11 members
# Cluster 9777 has 10 members
# Cluster 9778 has 9 members
# Cluster 9779 has 11 members
# Cluster 9780 has 12 members
# Cluster 9781 has 10 members
# Cluster 9782 has 10 members
# Cluster 9783 has 9 members
# Cluster 9784 has 13 members
# Cluster 9785 has 7 members
# Cluster 9786 has 7 members
# Cluster 9787 has 7 members
# Cluster 9788 has 9 members
# Cluster 9789 has 8 members
# Cluster 9790 has 8 members
# Cluster 9791 has 5 members
# Cluster 9792 has 8 members
# Cluster 9793 has 9 members
# Cluster 9794 has 6 members
# Cluster 9795 has 8 members
# Cluster 9796 has 10 members
# Cluster 9797 has 13 members
# Cluster 9798 has 7 members
# Cluster 9799 has 15 members
# Cluster 9800 has 9 members
# Cluster 9801 has 9 members
# Cluster 9802 has 6 members
# Cluster 9803 has 8 members
# Cluster 9804 has 9 members
# Cluster 9805 has 8 members
# Cluster 9806 has 5 members
# Cluster 9807 has 14 members
# Cluster 9808 has 6 members
# Cluster 9809 has 8 members
# Cluster 9810 has 7 members
# Cluster 9811 has 10 members
# Cluster 9812 has 8 members
# Cluster 9813 has 8 members
# Cluster 9814 has 8 members
# Cluster 9815 has 9 members
# Cluster 9816 has 8 members
# Cluster 9817 has 12 members
# Cluster 9818 has 9 members
# Cluster 9819 has 13 members
# Cluster 9820 has 7 members
# Cluster 9821 has 14 members
# Cluster 9822 has 12 members
# Cluster 9823 has 7 members
# Cluster 9824 has 15 members
# Cluster 9825 has 7 members
# Cluster 9826 has 8 members
# Cluster 9827 has 8 members
# Cluster 9828 has 9 members
# Cluster 9829 has 8 members
# Cluster 9830 has 6 members
# Cluster 9831 has 5 members
# Cluster 9832 has 8 members
# Cluster 9833 has 9 members
# Cluster 9834 has 8 members
# Cluster 9835 has 9 members
# Cluster 9836 has 10 members
# Cluster 9837 has 7 members
# Cluster 9838 has 9 members
# Cluster 9839 has 8 members
# Cluster 9840 has 8 members
# Cluster 9841 has 11 members
# Cluster 9842 has 7 members
# Cluster 9843 has 11 members
# Cluster 9844 has 7 members
# Cluster 9845 has 13 members
# Cluster 9846 has 16 members
# Cluster 9847 has 15 members
# Cluster 9848 has 10 members
# Cluster 9849 has 10 members
# Cluster 9850 has 9 members
# Cluster 9851 has 9 members
# Cluster 9852 has 6 members
# Cluster 9853 has 7 members
# Cluster 9854 has 9 members
# Cluster 9855 has 10 members
# Cluster 9856 has 9 members
# Cluster 9857 has 13 members
# Cluster 9858 has 7 members
# Cluster 9859 has 8 members
# Cluster 9860 has 9 members
# Cluster 9861 has 15 members
# Cluster 9862 has 10 members
# Cluster 9863 has 12 members
# Cluster 9864 has 8 members
# Cluster 9865 has 9 members
# Cluster 9866 has 6 members
# Cluster 9867 has 10 members
# Cluster 9868 has 8 members
# Cluster 9869 has 6 members
# Cluster 9870 has 10 members
# Cluster 9871 has 10 members
# Cluster 9872 has 9 members
# Cluster 9873 has 7 members
# Cluster 9874 has 8 members
# Cluster 9875 has 8 members
# Cluster 9876 has 8 members
# Cluster 9877 has 9 members
# Cluster 9878 has 7 members
# Cluster 9879 has 7 members
# Cluster 9880 has 8 members
# Cluster 9881 has 7 members
# Cluster 9882 has 5 members
# Cluster 9883 has 11 members
# Cluster 9884 has 6 members
# Cluster 9885 has 9 members
# Cluster 9886 has 9 members
# Cluster 9887 has 10 members
# Cluster 9888 has 8 members
# Cluster 9889 has 15 members
# Cluster 9890 has 7 members
# Cluster 9891 has 6 members
# Cluster 9892 has 14 members
# Cluster 9893 has 10 members
# Cluster 9894 has 9 members
# Cluster 9895 has 11 members
# Cluster 9896 has 11 members
# Cluster 9897 has 8 members
# Cluster 9898 has 8 members
# Cluster 9899 has 8 members
# Cluster 9900 has 8 members
# Cluster 9901 has 11 members
# Cluster 9902 has 9 members
# Cluster 9903 has 7 members
# Cluster 9904 has 7 members
# Cluster 9905 has 6 members
# Cluster 9906 has 9 members
# Cluster 9907 has 11 members
# Cluster 9908 has 7 members
# Cluster 9909 has 10 members
# Cluster 9910 has 6 members
# Cluster 9911 has 6 members
# Cluster 9912 has 9 members
# Cluster 9913 has 4 members
# Cluster 9914 has 6 members
# Cluster 9915 has 8 members
# Cluster 9916 has 7 members
# Cluster 9917 has 7 members
# Cluster 9918 has 9 members
# Cluster 9919 has 9 members
# Cluster 9920 has 9 members
# Cluster 9921 has 9 members
# Cluster 9922 has 13 members
# Cluster 9923 has 9 members
# Cluster 9924 has 10 members
# Cluster 9925 has 5 members

# %%
# Out:
# {'HOMAN C': 0,
#  'BERTOLINI S': 0,
#  'SHESTOVA E': 0,
#  'TERZI P': 0,
#  'ALVIN J': 0,
#  'BRUZINA R': 0,
#  'BADGER L': 1,
#  'BANHAM G': 0,
#  'BEHNKE E': 0,
#  'DASTUR F': 1,
#  'DEPRAZ N': 0,
#  'DUPONT C': 0,
#  'GIUBIATO G': 0,
#  'GIUBILATO G': 0,
#  'GRONDIN J': 1,
#  'GRONDIN V': 0,
#  'HART J': 0,
#  'HENRY M': 1,
#  'HIMANKA J': 0,
#  'HOBBS D': 0,
#  'IKEDA Y': 0,
#  'INVERSO H': 0,
#  'LEE E': 2,
#  'LORELLE P': 0,
#  'MASI F': 0,
#  'MORAN D': 0,
#  'NIEL L': 0,
#  'ONATE A': 0,
#  'PLOTKA W': 0,
#  'ROGGERO J': 1,
#  'SAKAKIBARA T': 0,
#  'SMYTH B': 2,
#  'VECINO M': 0,
#  'WEBER J': 0,
#  'BARBER M': 3,
#  'CAIRNS D': 0,
#  'BEGOUT B': 0,
#  'BERNASCONI R': 1,
#  'BESOLI S': 0,
#  'BOJANIC P': 2,
#  'BRIEDIS M': 0,
#  'BRISART R': 0,
#  'BRUDZINSKA J': 0,
#  'CHERNAVIN G': 0,
#  'CORA G': 1,
#  'DE P': 0,
#  'DONOHOE J': 0,
#  'DOYON M': 0,
#  'DWYER D': 0,
#  'EDIE J': 0,
#  'EMBREE L': 0,
#  'FALCON L': 0,
#  'FLYNN T': 2,
#  'GONNELLA S': 0,
#  'GROS A': 3,
#  'HAUSER K': 4,
#  'HOLMES R': 0,
#  'HOPKINS B': 0,
#  'HUGHES D': 0,
#  'HUSSERL E': 0,
#  'IJSSELING S': 1,
#  'JARAN F': 0,
#  'KRISTJANSSON K': 5,
#  'KWAN T': 3,
#  'LEASK I': 0,
#  'LEE N': 0,
#  'LOZAR J': 1,
#  'MICHEL B': 0,
#  'MOONEY T': 2,
#  'NEMETH T': 0,
#  'NI L': 0,
#  'PINTOS P': 0,
#  'RABANAQUE L': 0,
#  'ROPERO N': 0,
#  'SEPP H': 0,
#  'SOBERANO R': 0,
#  'SOKOLOWSKI R': 0,
#  'THEODOROU P': 0,
#  'TRAKAKIS N': 1,
#  'ZIPPEL N': 0,
#  'CROWE B': 1,
#  'CAPOBIANCO R': 1,
#  'FIELD J': 1,
#  'KENNEDY T': 1,
#  'SHEEHAN T': 1,
#  'ADRIAN J': 1,
#  'DAHLSTROM D': 1,
#  'ALTMAN M': 1,
#  'ALTOBRANDO A': 0,
#  'ANDERSEN N': 6,
#  'AVERCHI M': 0,
#  'BERTORELLO A': 1,
#  'BROGAN M': 1,
#  'BROWNLEE T': 6,
#  'BURCH M': 1,
#  'CALABRESSE C': 1,
#  'DE L': 6,
#  'ENGELLAND C': 1,
#  'FAGENBLAT M': 1,
#  'FERENCZ F': 0,
#  'FERRER R': 1,
#  'FEYAERTS J': 0,
#  'FLAMARIQUE L': 1,
#  'JACOBS H': 0,
#  'KINKAID J': 0,
#  'LANGBEHN C': 1,
#  'LIBERATI N': 7,
#  'MCMANUS D': 1,
#  'O L': 1,
#  'O R': 1,
#  'OVERGAARD S': 0,
#  'RADINKOVIC Z': 0,
#  'SCHALOW F': 1,
#  'SCULT A': 1,
#  'SERON D': 0,
#  'STUNKEL K': 1,
#  'TANZER M': 1,
#  'TRATTER A': 1,
#  'WALSH P': 5,
#  'WRATHALL M': 1,
#  'ZOLLER D': 1,
#  'AGGLETON S': 2,
#  'FINK E': 0,
#  'ALDEA A': 0,
#  'ALLOA E': 2,
#  'ARANDATORRES C': 6,
#  'ARGUELLES F': 3,
#  'ASCARATE L': 1,
#  'BARKER J': 2,
#  'BECKMANN Z': 0,
#  'BJORK U': 2,
#  'BLECHA I': 1,
#  'BOROBIA J': 0,
#  'BRENNAN E': 1,
#  'CABRERA C': 0,
#  'CAI W': 0,
#  'CAMILLERI S': 1,
#  'CAVALLARO M': 0,
#  'CERBONE D': 4,
#  'CHRISTENSEN J': 1,
#  'CIBULKA J': 1,
#  'COPILAS E': 6,
#  'COSTELLOE T': 0,
#  'CRISTIN R': 0,
#  'CROWELL S': 0,
#  'DAVIDSON S': 1,
#  'DE N': 0,
#  'DE W': 0,
#  'DECLERCK G': 8,
#  'DETISTOVA A': 1,
#  'ELDRIDGE P': 0,
#  'ELLISTON F': 0,
#  'FORSTER W': 6,
#  'GARCIA E': 2,
#  'GARRIDO J': 1,
#  'GHANOTAKIS G': 1,
#  'GHITTI J': 1,
#  'GIRARDI L': 0,
#  'GRUNER S': 6,
#  'GUERRERO J': 0,
#  'GUILLEN G': 0,
#  'GUPTA B': 0,
#  'HART K': 1,
#  'HEINAMAA S': 0,
#  'HOGENOVA A': 1,
#  'JANER D': 3,
#  'JOHNSON F': 1,
#  'JONKUS D': 0,
#  'KINGWELL M': 0,
#  'KISIEL T': 1,
#  'KOCHLER H': 0,
#  'KONONETC D': 0,
#  'KUNSCHOVA J': 0,
#  'LAHBIB O': 2,
#  'LAWLOR L': 2,
#  'LELAND D': 0,
#  'LIEBSCH B': 1,
#  'LORIES D': 0,
#  'LOSONCZ M': 0,
#  'LOZANO A': 7,
#  'LUFT S': 0,
#  'MARBACH E': 0,
#  'MCGUIRK J': 0,
#  'MOCKEL C': 0,
#  'MOHANTY J': 0,
#  'NG C': 0,
#  'NITTA Y': 2,
#  'NOVOTNY K': 1,
#  'ORTH E': 0,
#  'OWEN I': 0,
#  'PERRI T': 2,
#  'PLANTE M': 0,
#  'POGREBNYAK A': 2,
#  'POZO A': 0,
#  'PROLE D': 0,
#  'PUGLIESE A': 0,
#  'RAPIC S': 0,
#  'RODRIGUEZ R': 1,
#  'ROMANO C': 1,
#  'SAENZ M': 2,
#  'SASS L': 8,
#  'SAVIN A': 0,
#  'SCHALLER K': 3,
#  'SCHUHMANN K': 0,
#  'SERBAN C': 0,
#  'SHEETS J': 7,
#  'SHOLOKHOVA S': 8,
#  'SRUBAR I': 3,
#  'STANCIU O': 0,
#  'STAUDIGL M': 1,
#  'STEINBOCK A': 0,
#  'STERNAD C': 1,
#  'STRASSER S': 0,
#  'SUMMA M': 7,
#  'SZEFTEL M': 0,
#  'TORRALBO A': 6,
#  'TRNKA J': 0,
#  'VAN DUPPEN Z': 8,
#  'VANDEPITTE M': 0,
#  'VARELA P': 1,
#  'WALDENFELS B': 2,
#  'WATSON S': 2,
#  'WEBB J': 0,
#  'WHITMOYER K': 2,
#  'WU Z': 0,
#  'YAMPOLSKAYA A': 1,
#  'ZAHAVI D': 0,
#  'ZIRION A': 0,
#  'ABALO F': 1,
#  'HEIDEGGER M': 1,
#  'ABBOTT M': 1,
#  'ABROMEIT J': 6,
#  'ACCETTI C': 9,
#  'AFFIFI R': 7,
#  'AI S': 2,
#  'AINBINDER B': 6,
#  'AL S': 2,
#  'ALMOG M': 1,
#  'ALVES P': 0,
#  'ALVIS J': 1,
#  'ANANIEVA E': 0,
#  'ANDERSON T': 1,
#  'ANDRUS G': 1,
#  'ANGELOVA E': 6,
#  'ANGUS I': 0,
#  'ARAGONA M': 8,
#  'ARBIB D': 1,
#  'AREL J': 6,
#  'ARTEMENKO N': 1,
#  'ARVIDSON P': 2,
#  'ATKINS R': 10,
#  'BABICH B': 2,
#  'BACIU C': 1,
#  'BALLANFAT E': 1,
#  'BALLARD B': 1,
#  'BALTAZAR A': 1,
#  'BAPTIST G': 6,
#  'BARANOVSKAJA I': 1,
#  'BARBARAS R': 2,
#  'BARIZZA A': 1,
#  'BATHO D': 1,
#  'BAZ A': 11,
#  'BEATON M': 7,
#  'BEAULIEU A': 2,
#  'BEAVERS A': 7,
#  'BECHTOL H': 1,
#  'BEITH D': 2,
#  'BELGRANO M': 1,
#  'BELL S': 1,
#  'BELTRAMIN J': 1,
#  'BENDLOVA P': 2,
#  'BENGTSSON J': 1,
#  'BENNETT H': 5,
#  'BENOIST J': 0,
#  'BENSON B': 1,
#  'BERAN O': 11,
#  'BERGAMIN J': 7,
#  'BERGO B': 1,
#  'BERNINGER A': 8,
#  'BEYER C': 0,
#  'BILYK V': 2,
#  'BINKELMANN C': 6,
#  'BISCHIN M': 1,
#  'BIUSO A': 8,
#  'BLANC S': 2,
#  'BLOCK N': 5,
#  'BLOK V': 1,
#  'BLOSSER P': 0,
#  'BOEDEKER E': 0,
#  'BORREN M': 1,
#  'BOURDEAU M': 1,
#  'BOURGEOIS P': 2,
#  'BOUYER G': 7,
#  'BOWMAN B': 6,
#  'BOZIC A': 1,
#  'BRAUDE H': 8,
#  'BREDLAU S': 7,
#  'BRIER S': 7,
#  'BUCKLEY M': 6,
#  'BURCHILL L': 2,
#  'BURKE M': 2,
#  'BURNS L': 1,
#  'BYLE N': 1,
#  'CAI X': 9,
#  'CALCAGNO A': 1,
#  'CANEO S': 0,
#  'CANNON B': 8,
#  'CAPEK J': 1,
#  'CAPRETTO P': 1,
#  'CAPUTO A': 1,
#  'CAPUTO J': 1,
#  'CARASSAI M': 1,
#  'CARDO J': 1,
#  'CAREL H': 8,
#  'CARRARA O': 1,
#  'CASUCCI M': 1,
#  'CATENA M': 2,
#  'CAZEAUX C': 2,
#  'CAZZANELLI S': 1,
#  'CEA F': 1,
#  'CERCEL G': 1,
#  'CERNY J': 1,
#  'CHAN W': 12,
#  'CHARLAND M': 1,
#  'CHEN X': 12,
#  'CHEN Y': 0,
#  'CHEN Z': 1,
#  'CHEUNG C': 11,
#  'CHIAPPE A': 1,
#  'CHIEREGHIN F': 6,
#  'CHILLON J': 1,
#  'CHIMISSO C': 2,
#  'CHOI K': 0,
#  'CHUKWUELOBE M': 2,
#  'CHUNG M': 1,
#  'CIARAMELLI F': 1,
#  'CIOCAN C': 1,
#  'CLIFTON S': 1,
#  'COATE M': 0,
#  'COECKELBERGH M': 7,
#  'COHEN J': 5,
#  'COHEN L': 5,
#  'COHEN R': 1,
#  'COLLINS A': 1,
#  'COLONY T': 1,
#  'COMPTON J': 7,
#  'CONILL J': 6,
#  'CONTI R': 6,
#  'CONTY A': 7,
#  'COPELJ E': 0,
#  'CORAZZA O': 7,
#  'CORBEIL Y': 1,
#  'COSERU C': 12,
#  'COSTA V': 0,
#  'COURTINE J': 1,
#  'COZMA C': 1,
#  'CRIPPEN M': 7,
#  'CRISTALDI G': 1,
#  'CSORDAS T': 3,
#  'CUEVAS J': 6,
#  'CULBERTSON C': 7,
#  'D A': 5,
#  'DA S': 2,
#  'DAHL E': 1,
#  'DALISSIER M': 2,
#  'DALTON D': 2,
#  'DAVENPORT J': 1,
#  'DE B': 7,
#  'DE C': 2,
#  'DE G': 2,
#  'DE H': 5,
#  'DE J': 7,
#  'DE M': 2,
#  'DE O': 1,
#  'DE S': 0,
#  'DEBOER T': 0,
#  'DELANCEY C': 5,
#  'DELAY S': 1,
#  'DEMICHIEL Y': 6,
#  'DENNES M': 0,
#  'DEPP D': 1,
#  'DESOUZA N': 7,
#  'DETTLOFF D': 1,
#  'DEWS P': 6,
#  'DI C': 1,
#  'DI M': 0,
#  'DINCOVICI A': 3,
#  'DINGS R': 7,
#  'DINKINS C': 1,
#  'DIREK Z': 2,
#  'DJIAN A': 1,
#  'DO C': 0,
#  'DODD J': 5,
#  'DOKUCHAYEV I': 6,
#  'DOLEZAL L': 2,
#  'DORFMAN E': 2,
#  'DOTOV D': 7,
#  'DREYFUS H': 7,
#  'DUBOST M': 1,
#  'DUCROS P': 1,
#  'DUNAGAN C': 5,
#  'DUQUE C': 0,
#  'DURANTE M': 1,
#  'DURD O': 1,
#  'DURIE R': 2,
#  'DUSSERT J': 2,
#  'DUVAL R': 1,
#  'EARNSHAW O': 10,
#  'EDWARDS C': 1,
#  'ELPIDOROU A': 5,
#  'ENNIS P': 1,
#  'ERHARD C': 5,
#  'ESCUDERO J': 1,
#  'ESPOSITO C': 1,
#  'ESTRADA J': 1,
#  'EVENSEN K': 7,
#  'FABRI M': 1,
#  'FABRIS A': 1,
#  'FALOUE E': 1,
#  'FALQUE E': 1,
#  'FAMELI P': 2,
#  'FEENBERG A': 7,
#  'FERNANDES M': 1,
#  'FERNANDEZ A': 8,
#  'FERNANDEZ J': 5,
#  'FIGAL G': 1,
#  'FISHER T': 1,
#  'FLORES P': 1,
#  'FORESTIER F': 1,
#  'FORMISANO R': 1,
#  'FRAISOPI F': 1,
#  'FREYDBERG B': 1,
#  'FRITSCHE J': 1,
#  'FROEHLICH J': 2,
#  'FROESE T': 7,
#  'FUJIWARA G': 2,
#  'FUNKE G': 0,
#  'GABELLIERI E': 1,
#  'GAHRN A': 7,
#  'GAITSCH P': 0,
#  'GALLAGHER S': 7,
#  'GALLEGOS F': 5,
#  'GAMBOA L': 1,
#  'GARCIA A': 8,
#  'GARRERA T': 1,
#  'GASCHE R': 0,
#  'GAUVRY C': 1,
#  'GERARD V': 0,
#  'GERL F': 1,
#  'GIAMBASTIANI V': 1,
#  'GIBBS P': 10,
#  'GIER N': 11,
#  'GILABERT F': 1,
#  'GILDERSLEEVE M': 10,
#  'GINEV D': 1,
#  'GJESDAL K': 6,
#  'GODWAY E': 2,
#  'GOGUEN J': 7,
#  'GONZALEZ F': 1,
#  'GONZALEZ J': 5,
#  'GORGONE S': 13,
#  'GORNER P': 1,
#  'GOSETTI F': 7,
#  'GOURDAIN S': 1,
#  'GRAHOVAC V': 6,
#  'GRANT S': 1,
#  'GRATTON P': 1,
#  'GRAVES A': 1,
#  'GREISCH J': 1,
#  'GRICOSKI T': 0,
#  'GRIFFERO T': 13,
#  'GRIMWOOD T': 13,
#  'GRITTEN A': 1,
#  'GRON A': 1,
#  'GROSSHEIM M': 13,
#  'GROTH M': 11,
#  'GSCHWANDTNER C': 1,
#  'GUARDIOLA J': 9,
#  'GUIDETTI L': 0,
#  'GUTAUSKAS M': 1,
#  'GUZMAN C': 1,
#  'HAINIC C': 1,
#  'HANSON J': 1,
#  'HAO Y': 0,
#  'HASSE J': 13,
#  'HAVERKAMP A': 1,
#  'HEATON J': 11,
#  'HEDERMAN M': 1,
#  'HEELAN P': 7,
#  'HEFFERNAN G': 0,
#  'HEIM M': 12,
#  'HEINER B': 7,
#  'HELD K': 0,
#  'HENG W': 1,
#  'HENGEHOLD L': 2,
#  'HENRIKSEN M': 8,
#  'HERRERA H': 1,
#  'HERSCH E': 1,
#  'HERVAS A': 6,
#  'HICKERSON R': 0,
#  'HILLS J': 10,
#  'HIRANO T': 0,
#  'HIROTA D': 1,
#  'HODGE J': 1,
#  'HOFFMANN T': 6,
#  'HOLZER W': 2,
#  'HORNER R': 1,
#  'HORUJY S': 3,
#  'HOTTOIS G': 1,
#  'HOUSSET E': 1,
#  'HRNJEZ S': 6,
#  'HUANG W': 0,
#  'HUBICK J': 1,
#  'HUI Y': 1,
#  'HUNTINGTON P': 12,
#  'HUTH M': 2,
#  'IAIA G': 1,
#  'INCE K': 2,
#  'INISHEV I': 1,
#  'IONEL L': 5,
#  'JACOBSON K': 2,
#  'JACQUES W': 1,
#  'JAMES S': 2,
#  'JANICAUD D': 1,
#  'JAROS M': 2,
#  'JAUME P': 2,
#  'JELSCHA S': 6,
#  'JIN X': 1,
#  'JOHNSON E': 1,
#  'JONES A': 2,
#  'JONES T': 1,
#  'JOOS E': 2,
#  'JORGENSEN D': 1,
#  'JOSL J': 1,
#  'JUOZELIS E': 10,
#  'JUZEFOVIC A': 1,
#  'KACERAUSKAS T': 1,
#  'KACHERAUSKAS T': 2,
#  'KALAN V': 1,
#  'KANABUS B': 1,
#  'KAUFER S': 1,
#  'KEARNEY R': 1,
#  'KEEPING J': 2,
#  'KENAAN H': 1,
#  'KENNY R': 1,
#  'KENNY Y': 1,
#  'KIM A': 0,
#  'KIMMERLE H': 6,
#  'KIRKLAND S': 1,
#  'KISSEL T': 1,
#  'KITTLER F': 6,
#  'KLASSEN A': 2,
#  'KLEIN R': 6,
#  'KLUCK S': 13,
#  'KOHAK E': 1,
#  'KOMEL D': 1,
#  'KONACHEVA S': 1,
#  'KOUBA P': 1,
#  'KOUBOVA A': 1,
#  'KOUKAL D': 0,
#  'KOVACS G': 1,
#  'KOZIN A': 1,
#  'KRASSOY A': 1,
#  'KRETSCHEL V': 0,
#  'KROLICK S': 0,
#  'KUHN R': 1,
#  'KULIKOV S': 1,
#  'KUUSELA O': 11,
#  'KVASZ L': 4,
#  'LABOOY G': 1,
#  'LABRADOR J': 1,
#  'LACEY J': 5,
#  'LAFAYE C': 6,
#  'LAMBERT G': 1,
#  'LANDES D': 2,
#  'LANIGAN R': 3,
#  'LANNOY J': 1,
#  'LAUER C': 6,
#  'LAZARIN M': 1,
#  'LAZIC D': 13,
#  'LEBRUN J': 1,
#  'LEGHISSA G': 0,
#  'LEGRAND D': 7,
#  'LELONG F': 1,
#  'LENGYEL Z': 1,
#  'LEUNG K': 0,
#  'LEVIN K': 7,
#  'LIN G': 1,
#  'LIN Y': 5,
#  'LIVINGSTON P': 5,
#  'LLEWELYN J': 1,
#  'LLORENTE J': 1,
#  'LLOYD R': 1,
#  'LOHT S': 1,
#  'LONG J': 1,
#  'LOTZ C': 0,
#  'LUCHTE J': 1,
#  'LUH J': 1,
#  'LUMSDEN S': 6,
#  'LUNA J': 1,
#  'LUSHCH U': 1,
#  'LYSEMOSE K': 1,
#  'MACANN C': 1,
#  'MACAVOY L': 1,
#  'MACDONALD P': 0,
#  'MACHADO R': 1,
#  'MACLAREN K': 7,
#  'MADARY M': 5,
#  'MADEIRA L': 8,
#  'MAGGINI G': 1,
#  'MAJOLINO C': 0,
#  'MAJOR L': 1,
#  'MAKUROVA A': 1,
#  'MALAFOURIS L': 7,
#  'MALL R': 0,
#  'MANOUSSAKIS J': 1,
#  'MANZI R': 1,
#  'MARAMBIO J': 0,
#  'MARANDOLA E': 2,
#  'MARASSI M': 1,
#  'MARDER M': 1,
#  'MARION J': 1,
#  'MARION Z': 1,
#  'MARSH J': 6,
#  'MARTIN W': 0,
#  'MARTINI R': 1,
#  'MATEJCKOVA T': 6,
#  'MATHERNE S': 7,
#  'MCCOWN J': 1,
#  'MCDANIEL K': 5,
#  'MCDONOUGH R': 5,
#  'MCKINNEY T': 1,
#  'MCNEILL W': 1,
#  'MEACHAM D': 2,
#  'MEANA D': 1,
#  'MEHL E': 1,
#  'MEJIA L': 1,
#  'MELANEY W': 1,
#  'MENDOLA G': 6,
#  'MENSCH J': 0,
#  'MERAZ F': 1,
#  'MERRITT M': 7,
#  'MEYER M': 13,
#  'MEZEI B': 1,
#  'MICHELOW D': 1,
#  'MICKEVICIUS A': 1,
#  'MIETTINEN T': 0,
#  'MIKA C': 2,
#  'MIKLOWITZ P': 6,
#  'MILLER H': 1,
#  'MILLS N': 6,
#  'MILNE P': 2,
#  'MIOLLI G': 6,
#  'MITCHELL D': 2,
#  'MOLCHANOV V': 0,
#  'MONOD J': 9,
#  'MONTEMAYOR C': 7,
#  'MONTICELLI R': 1,
#  'MORAES A': 6,
#  'MORENO C': 1,
#  'MORENO M': 1,
#  'MORLEY J': 1,
#  'MORRIS D': 2,
#  'MOSKALEWICZ M': 8,
#  'MURANSKY M': 1,
#  'MURCHADHA F': 1,
#  'MURRAY M': 6,
#  'MURRAY S': 6,
#  'MYIN E': 7,
#  'NAKHUTSRISHVILI L': 1,
#  'NELSON E': 1,
#  'NENON T': 0,
#  'NITSCHE M': 1,
#  'NOPPEN P': 1,
#  'O C': 1,
#  'O M': 1,
#  'OBERT M': 13,
#  'OGAWA T': 0,
#  'OINAM B': 2,
#  'OKRENT M': 1,
#  'OLIVIER A': 5,
#  'OLKOWSKI D': 2,
#  'OLLAGNIER B': 7,
#  'ORDONEZ A': 2,
#  'ORGANISTI U': 1,
#  'ORR J': 1,
#  'OVERENGET E': 1,
#  'PAGE J': 7,
#  'PAIC Z': 6,
#  'PALEY J': 10,
#  'PALOMBI F': 4,
#  'PANTANO A': 1,
#  'PANTYKINA M': 3,
#  'PARK B': 11,
#  'PATKUL A': 1,
#  'PATOCKA J': 1,
#  'PATRAS F': 4,
#  'PATTISON G': 1,
#  'PAUZA M': 1,
#  'PAVAN C': 8,
#  'PEARSON K': 1,
#  'PEPERZAK A': 1,
#  'PEREGO V': 1,
#  'PEREZ B': 6,
#  'PERINAN J': 1,
#  'PERIUS C': 2,
#  'PETROVIC E': 2,
#  'PIANA G': 1,
#  'PIETERSMA H': 0,
#  'PIMENTEL D': 1,
#  'PIRC G': 1,
#  'PLANT B': 1,
#  'PODVOYSKIY D': 1,
#  'POELLNER P': 5,
#  'POMMIER E': 1,
#  'POPA D': 0,
#  'POPOV V': 0,
#  'POPOVIC U': 13,
#  'POREE J': 1,
#  'POTT H': 5,
#  'POTTER B': 1,
#  'POWELL J': 1,
#  'PRADELLE D': 0,
#  'PRASEK P': 1,
#  'PREVOT A': 1,
#  'PROSSER A': 7,
#  'PURCELL M': 1,
#  'QUAEGHEBEUR L': 7,
#  'QUEPONS I': 0,
#  'RABANUS C': 1,
#  'RAFFOUL F': 1,
#  'RAMIREZ M': 2,
#  'RAMOS D': 1,
#  'RAMSEY C': 1,
#  'RATCLIFFE M': 8,
#  'RAYMAN J': 6,
#  'REDFIELD J': 2,
#  'REID H': 6,
#  'RENAUDIE P': 0,
#  'REYNOLDS J': 2,
#  'RICE D': 2,
#  'RICOEUR P': 1,
#  'RIIS S': 1,
#  'RISSER J': 1,
#  'RITTER M': 1,
#  'RIVERA J': 1,
#  'ROCKMORE T': 6,
#  'RODRIGUEZ J': 1,
#  'ROESNER M': 1,
#  'RONEY P': 1,
#  'ROTH J': 2,
#  'ROUBACH M': 2,
#  'ROUSSE B': 6,
#  'ROZIN V': 1,
#  'RUDD A': 1,
#  'RUI X': 1,
#  'RUSSELL M': 1,
#  'RUSSON J': 6,
#  'RYABUSHKINA T': 0,
#  'SABOLIUS K': 1,
#  'SAEVI T': 13,
#  'SALDUKAITYTE J': 1,
#  'SALIN A': 7,
#  'SALTER M': 6,
#  'SAMPATH R': 1,
#  'SANCHEZ C': 11,
#  'SANCHEZ J': 6,
#  'SANTOS B': 1,
#  'SANTOS G': 1,
#  'SARAGA M': 8,
#  'SASSINE M': 9,
#  'SCARSO D': 2,
#  'SCHEAR J': 7,
#  'SCHEIDEGGER J': 1,
#  'SCHENK D': 1,
#  'SCHLIMME J': 8,
#  'SCHMID H': 5,
#  'SCHMIDT D': 6,
#  'SCHNELL A': 1,
#  'SCHREINER C': 3,
#  'SCHRIJVERS J': 1,
#  'SCHROEDER B': 2,
#  'SCHUBACK M': 0,
#  'SCHUFREIDER G': 13,
#  'SEBA J': 6,
#  'SEIBT C': 1,
#  'SEIGFRIED H': 1,
#  'SENA M': 1,
#  'SENGUPTA R': 7,
#  'SERCK H': 6,
#  'SERNELJ T': 6,
#  'SEYLER F': 1,
#  'SHUSTER M': 6,
#  'SILVA C': 2,
#  'SILVERMAN H': 2,
#  'SIMMONS J': 1,
#  'SIMMS E': 2,
#  'SINNERBRINK R': 2,
#  'SIVAK J': 1,
#  'SKIRKE C': 5,
#  'SKOCZ D': 2,
#  'SKYRTACH V': 3,
#  'SLABY J': 5,
#  'SLAMA P': 1,
#  'SMID R': 0,
#  'SMITH D': 0,
#  'SMITH J': 5,
#  'SMITH S': 7,
#  'SOBOTKA M': 6,
#  'SOMMER M': 2,
#  'SPAAK C': 0,
#  'SPARROW T': 2,
#  'SPIEGELBERG H': 0,
#  'SPITZER C': 1,
#  'ST L': 1,
#  'STAEHLER T': 1,
#  'STAGI P': 0,
#  'STANCHINA G': 12,
#  'STANGHELLINI G': 8,
#  'STAPLETON T': 0,
#  'STASIULIS N': 1,
#  'STEEVES H': 13,
#  'STEGMAIER W': 3,
#  'STENGER G': 13,
#  'STEPHENSEN H': 8,
#  'STERLICIII P': 1,
#  'STEVENSON K': 10,
#  'STIVIC S': 1,
#  'STOKES P': 1,
#  'STOLLER S': 2,
#  'STONE A': 2,
#  'STONE D': 1,
#  'STREUBEL T': 0,
#  'STRUYKERBOUDIER C': 1,
#  'STUART S': 7,
#  'SUAREZ D': 5,
#  'SVEC O': 2,
#  'SVENAEUS F': 8,
#  'SVETLIC R': 6,
#  'SWAZO N': 13,
#  'SWER G': 6,
#  'SZANTO T': 5,
#  'TAIPALE J': 0,
#  'TAKEICHI A': 1,
#  'TALERO M': 7,
#  'TALIA W': 1,
#  'TALLON A': 1,
#  'TAMINIAUX J': 1,
#  'TANG M': 1,
#  'TAPPER M': 1,
#  'TASSONE B': 1,
#  'TAYLOR M': 1,
#  'TERTULIAN N': 6,
#  'TEXTOR M': 5,
#  'THERIEN C': 1,
#  'THOLT P': 1,
#  'THOMPSON K': 5,
#  'THOMPSON M': 1,
#  'THOMSON I': 1,
#  'THROOP C': 10,
#  'TIAHA D': 1,
#  'TIESZEN R': 4,
#  'TIN M': 1,
#  'TOADVINE T': 2,
#  'TODARIYA S': 1,
#  'TOLEDO D': 1,
#  'TRAYLOR A': 1,
#  'TRCKA N': 13,
#  'TRIGG D': 2,
#  'TRIZIO E': 0,
#  'TROUBE S': 8,
#  'TUCKETT J': 3,
#  'TULLIUS W': 0,
#  'TYMAN S': 1,
#  'UEMURA G': 0,
#  'ULATE E': 1,
#  'URBAN P': 2,
#  'VAHABZADEH P': 3,
#  'VAJDA M': 1,
#  'VALERA L': 1,
#  'VALLEGA N': 1,
#  'VAN ATTEN M': 4,
#  'VAN DER LUFT E': 6,
#  'VAN DER SCHYFF D': 7,
#  'VAN HAUTE P': 2,
#  'VAN LEEUWEN A': 1,
#  'VANZAGO L': 7,
#  'VASTERLING V': 7,
#  'VAYSSE J': 1,
#  'VERBEEK P': 7,
#  'VIIK T': 3,
#  'VIRI F': 1,
#  'VISSER G': 2,
#  'VLASOVA O': 8,
#  'VOLPI F': 1,
#  'VON ZUBEN N': 1,
#  'VYDRA A': 2,
#  'WADDELL V': 8,
#  'WALTON R': 0,
#  'WANG J': 0,
#  'WANG W': 1,
#  'WARDLEY K': 1,
#  'WARGO V': 1,
#  'WEINBERGER D': 1,
#  'WEINER S': 6,
#  'WEINZWEIG M': 11,
#  'WELTON D': 0,
#  'WERTZ F': 2,
#  'WESTPHAL M': 1,
#  'WHEELER M': 7,
#  'WIGGINS O': 8,
#  'WILLIAMS A': 3,
#  'WILLIAMS J': 1,
#  'WITHY K': 1,
#  'WOOD D': 1,
#  'WOOD R': 1,
#  'WOODY M': 1,
#  'WRIGH C': 3,
#  'WU R': 5,
#  'WULF C': 0,
#  'WUNENBURGER J': 2,
#  'YANG D': 1,
#  'YANG W': 1,
#  'YOSHIMI J': 0,
#  'ZAIETTA L': 2,
#  'ZARADER M': 1,
#  'ZERVAN M': 2,
#  'ZEYNEP D': 1,
#  'ZIELKE D': 0,
#  'ZOCCHI E': 1,
#  'ZOPOLO A': 9,
#  'KANT I': 1,
#  'ALBERTINI F': 1,
#  'ALLAIS L': 7,
#  'ALLEN W': 1,
#  'ALROE H': 7,
#  'ALWEISS L': 0,
#  'ANDERSON E': 1,
#  'ANDERSON P': 2,
#  'ANSELL P': 1,
#  'ATKINS K': 7,
#  'AUDI R': 5,
#  'BACHEV M': 1,
#  'BARBA K': 6,
#  'BARTHELEMY J': 0,
#  'BARZILAI D': 1,
#  'BELOUSOV M': 0,
#  'BELVEDERE C': 1,
#  'BEYLEVELD D': 6,
#  'BIRD P': 6,
#  'BLASI G': 2,
#  'BLOND L': 1,
#  'BOGOMILOVA N': 1,
#  'BOI L': 4,
#  'BORDINI D': 0,
#  'BREEUR R': 0,
#  'CALLANAN J': 6,
#  'CARLSSON U': 1,
#  'CHEPURIN K': 6,
#  'CHUDNOFF E': 5,
#  'COBBEN P': 6,
#  'CONILL S': 6,
#  'CROWTHER P': 2,
#  'CURZER H': 5,
#  'DAL M': 6,
#  'DE K': 6,
#  'DIGIOVANNI G': 6,
#  'DOERR Z': 8,
#  'DOS S': 2,
#  'DUFOURCQ A': 2,
#  'DUQUE J': 1,
#  'ELBERFELD R': 13,
#  'ENCHEV K': 1,
#  'FAILLA M': 6,
#  'FERNANDEZ H': 1,
#  'FERRER G': 0,
#  'FEYLES M': 1,
#  'FORD J': 5,
#  'FRIEDMAN M': 1,
#  'FROLOV A': 0,
#  'FUENTES J': 1,
#  'GANS S': 2,
#  'GAVA G': 6,
#  'GEIGER M': 0,
#  'GENIUSAS S': 0,
#  'GLOY K': 6,
#  'GORTZEN R': 6,
#  'GOTTSCHLICH M': 6,
#  'GRANDJEAN A': 6,
#  'GROHMANN T': 7,
#  'GRZIBOWSKI S': 1,
#  'HAHN S': 6,
#  'HELD L': 9,
#  'HERMS E': 1,
#  'HOERL C': 5,
#  'HOFFHEIMER M': 6,
#  'HORGAN T': 5,
#  'HOWIE G': 6,
#  'INKPIN A': 2,
#  'IRWIN B': 2,
#  ...}

# %%
# Save / re-open a partition
# pickle.dump(partition, open("partition_louvain.obj", "wb"))
# test = pickle.load(open("partition_louvain.obj", "rb"))

# %% [markdown]
# ### Girvan Newman
#
# Takes a long time...

# %%
partition_gn = girvan_newman(G_tiny_directed)

# %%
clusters_gn = unfold(partition_gn)

# %%
# print_clusters(G_tiny, clusters_gn) # Something is obviously wrong!

# %% [markdown]
# ### K Clique Communities

# %%
# Appears to be deterministic
clusters_kc = k_clique_communities(G_large,4)

# %%
list_kc = unfold(clusters_kc)

# %%
# print_clusters(G_tiny, list_kc)

# %%
# Cluster with 873 members
#                Name  In Degree
# 428       HUSSERL E        535
# 829     HEIDEGGER M        326
# 225  MERLEAUPONTY M        303

# %% [markdown]
# ## Greedy

# %%
# Appears to be deterministic
clusters_greedy = k_clique_communities(G_large, 5)

# %%
list_greedy = unfold(clusters_greedy)

# %%
print_clusters(G_large, list_greedy)

# %% [markdown]
# ## Draw graph

# %%
# nx.draw(G, node_size = 10, with_labels=True, font_size = 12)

# %% [markdown]
# ### Archived functions
# There may be some useful code fragments here
#
# Delete ASAP following the principle of commented out code is gross and should not be allowed to accumulate

# %%
def print_clusters(graph, clusters):
    print("Graph has ",len(clusters), "clusters")
    for i,p in enumerate(clusters):
        print("Cluster",(i+1), "has", len(p), "members")
#         if (len(p) > 0):
#             for i2,p2 in enumerate(p):
#                 print("\tSubCluster",(i2+1), "has", len(p2), "members")
                
#         subgraph = graph.subgraph([i for i in list(p)])
#         print(subgraph)
#         table = pd.DataFrame(graph.degree, columns = ["Name","Degree"])
#         table = table.sort_values(by=['Degree'], ascending=False)
#         print(st.head(3))
#         print()

# %%
def print_community(community, hasmembers=True):
    print(len(community))
    if(hasmembers):
        for comm in community:
            print(comm)
    else:
        print(community)
