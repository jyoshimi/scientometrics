# %% [markdown]
# ### Install and run with
# https://git.skewed.de/count0/graph-tool/wikis/installation-instructions#installing-using-docker
#
# But I ended up installing with brew.  Hope it didn't overwriter anything else!

# %%
from graph_tool.all import *
import matplotlib.pyplot as plt

# %%
g = load_graph("./small_edge_list.graphml")

# %% [markdown]
# ## Todos
# Find vertex properties
#
# The stochastic block model (SBM)

# %% [markdown]
# ### Block Model
#
# https://graph-tool.skewed.de/static/doc/demos/inference/inference.html

# %%
state = minimize_blockmodel_dl(g)

# %%
plt.matshow(state.get_matrix().todense())

# %%
b = state.get_blocks()
# for r in b:
#     print(r)

# %%
g.list_properties()
# Out:
# _graphml_vertex_id (vertex)  (type: string)
# _graphml_edge_id (edge)    (type: string)
# weight         (edge)    (type: long double)

# %%
g.vertex(2)
# Out:
# <Vertex object with index '2' at 0x14cd547b0>

# %%
state.draw()
# Out:
# <VertexPropertyMap object with value type 'vector<double>', for Graph 0x1468f9a90, at 0x1467e8990>

# %% [markdown]
# ### Nested Model

# %%
state_nested = minimize_nested_blockmodel_dl(g)

# %%
print(state_nested)
# Out:
# <NestedBlockState object, with base <BlockState object with 35 blocks (35 nonempty), degree-corrected, for graph <Graph object, directed, with 4369 vertices and 41158 edges at 0x1097f9990>, at 0x17cee6710>, and 4 levels of sizes [(4369, 35), (35, 12), (12, 3), (3, 1)] at 0x17d418b10>

# %%
state_nested.draw()
# Out:
# (<VertexPropertyMap object with value type 'vector<double>', for Graph 0x1468f9a90, at 0x146c316d0>,
#  <Graph object, directed, with 4422 vertices and 4421 edges at 0x1038ad110>,
#  <VertexPropertyMap object with value type 'vector<double>', for Graph 0x1038ad110, at 0x176c88850>)

# %% [markdown]
# ### Other graph drawing methods
#
# https://graph-tool.skewed.de/static/doc/draw.html

# %%
# pos = fruchterman_reingold_layout(g, n_iter=1000) # Slow! Maybe try with lower iterattions

# %%
# graph_draw(g, pos=pos)

# %%
# !open .
